# %%
# %run ./1_config

# %%
from pyspark.sql import functions as F
for t in [conf.gold_geo_traffic_daily, conf.gold_fraud_signals, conf.gold_customer_features]:
    print(t, spark.table(conf.table_fqn(t)).count())
display(spark.table(conf.table_fqn(conf.gold_geo_traffic_daily)).orderBy(F.desc("event_count")))
