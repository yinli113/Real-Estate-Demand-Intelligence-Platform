# %%
# %run ./1_config
from pyspark.sql import functions as F
display(spark.table(conf.table_fqn(conf.gold_conversion_gaps)).orderBy(F.desc("views")))
display(spark.table(conf.table_fqn(conf.gold_interstate_flow)).orderBy(F.desc("views")))
